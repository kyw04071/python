# %%
# !pip install pandas
import xml.etree.ElementTree as et
tree = et.ElementTree(file='menu.xml')
root = tree.getroot()
print(root.tag)
# Out:
# Requirement already satisfied: pandas in c:\users\yw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (3.0.2)
# Requirement already satisfied: numpy>=2.3.3 in c:\users\yw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\yw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\yw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\yw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# menu
# [notice] A new release of pip is available: 25.3 -> 26.1
# [notice] To update, run: C:\Users\YW\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
for child in root :
    print('tag :', child.tag, 'attributes:', child.attrib)
    for grandchild in child:
        print('\ttag:', grandchild.tag,'attributes:', grandchild.attrib)
# Out:
# tag : breakfast attributes: {'hours': '7-11'}
# 	tag: item attributes: {'price': '$6.00'}
# 	tag: item attributes: {'price': '$4.00'}
# tag : lunch attributes: {'hours': '11-3'}
# 	tag: item attributes: {'price': '$5.00'}
# tag : dinner attributes: {'hours': '3-10'}
# 	tag: item attributes: {'price': '8.00'}

# %%
len(root)
# Out:
# 3

# %%
len(root[0])
# Out:
# 2

# %%
print(root[0])
print(root[0].get("hours"))
print(root[0].keys())
print(root[0].items())
# Out:
# <Element 'breakfast' at 0x000001C55E15EA70>
# 7-11
# ['hours']
# [('hours', '7-11')]

# %%
print(root[0].findall('item'))
# Out:
# [<Element 'item' at 0x000001C55E15EB60>, <Element 'item' at 0x000001C55E15EBB0>]

# %%
import json
j1 = {"name":"홍길동", "birth":"0525", "age": 30} 
j1 
print(json.dumps(j1, indent=2))
# Out:
# {
#   "name": "\ud64d\uae38\ub3d9",
#   "birth": "0525",
#   "age": 30
# }

# %%
 json.dumps([1,2,3])
# Out:
# '[1, 2, 3]'

# %%
json.dumps((4,5,6))
# Out:
# '[4, 5, 6]'

# %%
j1 = {"name":"홍길동", "birth":"0525", "age": 30} 
d1 = json.dumps(j1) 
json.loads(d1)
# Out:
# {'name': '홍길동', 'birth': '0525', 'age': 30}

# %%
with open('myinfo.json', encoding='utf-8') as f:
    data = json.load(f) 
    print(type(data)) 
    print(data)
# Out:
# <class 'dict'>
# {'name': '홍길동', 'birth': '0525', 'age': 30}

# %%
from urllib.request import urlopen
html = urlopen("http://pythonscraping.com/pages/page1.html")
print(html.read())
# Out:
# b'<html>\n<head>\n<title>A Useful Page</title>\n</head>\n<body>\n<h1>An Interesting Title</h1>\n<div>\nLorem ipsum dolor sit amet, consectetur adipisicing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.\n</div>\n</body>\n</html>\n'

# %%
from urllib.request import urlopen
html = urlopen("http://pythonscraping.com/pages/page1.html")
print(html.read())
# Out:
# b'<html>\n<head>\n<title>A Useful Page</title>\n</head>\n<body>\n<h1>An Interesting Title</h1>\n<div>\nLorem ipsum dolor sit amet, consectetur adipisicing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.\n</div>\n</body>\n</html>\n'

# %%
# !pip install bs4
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen("http://pythonscraping.com/pages/page1.html")
bsObj = BeautifulSoup(html.read(), "html.parser")
print(bsObj.h1)
# Out:
# Requirement already satisfied: bs4 in c:\users\yw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (0.0.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\yw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from bs4) (4.14.3)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\yw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from beautifulsoup4->bs4) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\yw\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from beautifulsoup4->bs4) (4.15.0)
# [notice] A new release of pip is available: 25.3 -> 26.1
# [notice] To update, run: C:\Users\YW\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip
# <h1>An Interesting Title</h1>
